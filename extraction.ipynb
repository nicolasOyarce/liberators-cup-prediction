# %%
import pandas as pd

# %%
all_tables = pd.read_html('https://en.wikipedia.org/wiki/Copa_Libertadores_2024')

# %%
all_tables[9]
# Out:
#    Pos        Teamvte  Pld  W  D  L  GF  GA  GD   Pts      Qualification  \
# 0    1     Fluminense    6  4  2  0   9   5  +4    14        Round of 16
# 1    2      Colo-Colo    6  1  3  2   4   5  −1  6[a]        Round of 16
# 2    3  Cerro Porteño    6  1  3  2   4   5  −1  6[a]  Copa Sudamericana
# 3    4   Alianza Lima    6  0  4  2   5   7  −2     4                NaN
#
#    Unnamed: 11  FLU  CCL  CCP  ALI
# 0          NaN    —  2–1  2–1  3–2
# 1          NaN  0–1    —  1–0  0–0
# 2          NaN  0–0  1–1    —  1–0
# 3          NaN  1–1  1–1  1–1    —
